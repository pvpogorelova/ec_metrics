# %%
# Загрузка неоходимых пакетов
install.packages("systemfit")
install.packages("foreign")
install.packages("car")
install.packages("rio")
install.packages("wooldridge")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘Rcpp’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘zoo’, ‘car’, ‘lmtest’, ‘sandwich’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘openxlsx’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Подключение библиотек
library(foreign)
library(systemfit) # системы регрессионных уравнений
library(car)
library(rio) # импорт данных
library(wooldridge) # датасет mroz
# Out:
# Loading required package: Matrix
#
# Loading required package: car
#
# Loading required package: carData
#
# Loading required package: lmtest
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
#
# Please cite the 'systemfit' package as:
# Arne Henningsen and Jeff D. Hamann (2007). systemfit: A Package for Estimating Systems of Simultaneous Equations in R. Journal of Statistical Software 23(4), 1-40. http://www.jstatsoft.org/v23/i04/.
#
# If you have questions, suggestions, or comments regarding the 'systemfit' package, please use a forum or 'tracker' at systemfit's R-Forge site:
# https://r-forge.r-project.org/projects/systemfit/

# %%
# SUR
# Пример из Вулдриджа
d = import("dataset-48043.csv")

r1 = hrearn ~ educ + exper + expersq + tenure + tenuresq + union + south + nrtheast + nrthcen + married + white + male
r2 = hrbens ~ educ + exper + expersq + tenure + tenuresq + union + south + nrtheast + nrthcen + married + white + male

fitsur = systemfit(list(hrearnreg = r1, hrbensreg = r2), data = d)
summary(fitsur)
# Out:
# systemfit results
# method: OLS
#
#           N   DF     SSR detRCov   OLS-R2 McElroy-R2
# system 1232 1206 11600.6 4.63027 0.208685   0.292642
#
#             N  DF       SSR       MSE     RMSE       R2   Adj R2
# hrearnreg 616 603 11437.037 18.966893 4.355100 0.205093 0.189274
# hrbensreg 616 603   163.544  0.271217 0.520785 0.398674 0.386708
#
# The covariance matrix of the residuals
#           hrearnreg hrbensreg
# hrearnreg 18.966893  0.716847
# hrbensreg  0.716847  0.271217
#
# The correlations of the residuals
#           hrearnreg hrbensreg
# hrearnreg   1.00000   0.31606
# hrbensreg   0.31606   1.00000
#
#
# OLS estimates for 'hrearnreg' (equation 1)
# Model Formula: hrearn ~ educ + exper + expersq + tenure + tenuresq + union +
#     south + nrtheast + nrthcen + married + white + male
#
#                Estimate  Std. Error  t value   Pr(>|t|)
# (Intercept) -2.63212671  1.22832151 -2.14286  0.0325236 *
# educ         0.45881395  0.06912628  6.63733 7.1256e-11 ***
# exper       -0.07584282  0.05734542 -1.32256  0.1864828
# expersq      0.00399449  0.00117795  3.39104  0.0007418 ***
# tenure       0.11008462  0.08380979  1.31351  0.1895122
# tenuresq    -0.00507064  0.00327692 -1.54738  0.1222965
# union        0.80799328  0.40780495  1.98132  0.0480089 *
# south       -0.45662223  0.55170344 -0.82766  0.4081912
# nrtheast    -1.15075861  0.60575425 -1.89971  0.0579478 .
# nrthcen     -0.63626628  0.55604484 -1.14427  0.2529651
# married      0.64238821  0.41779850  1.53756  0.1246820
# white        1.14089121  0.61193899  1.86439  0.0627530 .
# male         1.78470236  0.39800745  4.48409 8.7674e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.3551 on 603 degrees of freedom
# Number of observations: 616 Degrees of Freedom: 603
# SSR: 11437.036645 MSE: 18.966893 Root MSE: 4.3551
# Multiple R-Squared: 0.205093 Adjusted R-Squared: 0.189274
#
#
# OLS estimates for 'hrbensreg' (equation 2)
# Model Formula: hrbens ~ educ + exper + expersq + tenure + tenuresq + union +
#     south + nrtheast + nrthcen + married + white + male
#
#                 Estimate   Std. Error  t value   Pr(>|t|)
# (Intercept) -0.889747099  0.146883282 -6.05751 2.4342e-09 ***
# educ         0.076792360  0.008266154  9.28997 < 2.22e-16 ***
# exper        0.022564931  0.006857393  3.29060  0.0010581 **
# expersq     -0.000473359  0.000140860 -3.36049  0.0008272 ***
# tenure       0.053555571  0.010022015  5.34379 1.2924e-07 ***
# tenuresq    -0.001163631  0.000391856 -2.96954  0.0031010 **
# union        0.365908540  0.048765513  7.50343 2.2404e-13 ***
# south       -0.022686547  0.065972964 -0.34388  0.7310591
# nrtheast    -0.056746823  0.072436387 -0.78340  0.4336986
# nrthcen     -0.037998394  0.066492111 -0.57147  0.5678925
# married      0.057862604  0.049960547  1.15817  0.2472548
# white        0.090158182  0.073175962  1.23207  0.2184017
# male         0.268338264  0.047593923  5.63808 2.6438e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.520785 on 603 degrees of freedom
# Number of observations: 616 Degrees of Freedom: 603
# SSR: 163.543819 MSE: 0.271217 Root MSE: 0.520785
# Multiple R-Squared: 0.398674 Adjusted R-Squared: 0.386708

# %%
# Система одновременных уравнений
d = mroz
d
# Зададим спецификацию уравнений системы
H = hours ~ lwage + educ + age + kidslt6 + kidsge6 + nwifeinc
LW = lwage ~ hours + educ + exper + expersq
sys = list(H,LW)
sys
# Out:
#     inlf hours kidslt6 kidsge6 age educ wage   repwage hushrs husage ⋯ faminc
# 1   1    1610  1       0       32  12   3.3540 2.65    2708   34     ⋯ 16310
# 2   1    1656  0       2       30  12   1.3889 2.65    2310   30     ⋯ 21800
# 3   1    1980  1       3       35  12   4.5455 4.04    3072   40     ⋯ 21040
# 4   1     456  0       3       34  12   1.0965 3.25    1920   53     ⋯  7300
# 5   1    1568  1       2       31  14   4.5918 3.60    2000   32     ⋯ 27300
# 6   1    2032  0       0       54  12   4.7421 4.70    1040   57     ⋯ 19495
# 7   1    1440  0       2       37  16   8.3333 5.95    2670   37     ⋯ 21152
# 8   1    1020  0       0       54  12   7.8431 9.98    4120   53     ⋯ 18900
# 9   1    1458  0       2       48  12   2.1262 0.00    1995   52     ⋯ 20405
# 10  1    1600  0       2       39  12   4.6875 4.15    2100   43     ⋯ 20425
# 11  1    1969  0       1       33  12   4.0630 4.30    2450   34     ⋯ 32300
# 12  1    1960  0       1       42  11   4.5918 4.58    2375   47     ⋯ 28700
# 13  1     240  1       2       30  12   2.0833 0.00    2830   33     ⋯ 15500
# 14  1     997  0       2       43  12   2.2668 3.50    3317   46     ⋯ 16860
# 15  1    1848  0       1       43  10   3.6797 3.38    2024   45     ⋯ 31431
# 16  1    1224  0       3       35  11   1.3472 0.00    1694   38     ⋯ 19180
# 17  1    1400  0       2       43  12   3.2143 4.00    2156   45     ⋯ 18600
# 18  1     640  0       5       39  12   5.1750 2.25    2250   40     ⋯ 19151
# 19  1    2000  0       0       45  12   2.0000 2.30    2024   51     ⋯ 18100
# 20  1    1324  0       4       35  12   7.5529 3.94    2123   40     ⋯ 20300
# 21  1    2215  0       2       42  16   3.5052 3.30    4160   48     ⋯ 30419
# 22  1    1680  0       0       30  12   3.5714 3.80    2000   35     ⋯ 14090
# 23  1    1600  0       0       48  13   3.2500 3.26    2420   52     ⋯ 22679
# 24  1     800  0       0       45  12   3.2500 2.20    1150   53     ⋯ 12160
# 25  1    1955  1       1       31  12   2.1545 2.30    2024   31     ⋯ 12487
# 26  1     660  0       2       43  17   3.7879 0.00    1904   43     ⋯ 29850
# 27  1     525  0       0       59  12   4.0000 3.18    2448   53     ⋯ 18100
# 28  1    1904  0       3       32  12   4.7269 6.07    2000   33     ⋯ 26000
# 29  1    1516  1       0       31  17   7.2559 6.00    2390   30     ⋯ 26100
# 30  1     346  0       0       42  12   5.8671 6.39    1920   47     ⋯ 17730
# ⋮   ⋮    ⋮     ⋮       ⋮       ⋮   ⋮    ⋮      ⋮       ⋮      ⋮      ⋱ ⋮
# 724 0    0     0       2       41  12   NA     0.00    2165   46     ⋯ 12400
# 725 0    0     0       2       49   5   NA     0.00    2230   43     ⋯  6531
# 726 0    0     0       0       59   8   NA     0.00    1995   55     ⋯ 22422
# 727 0    0     0       0       58  13   NA     0.00    2025   57     ⋯ 22200
# 728 0    0     0       3       41  12   NA     0.00    2450   48     ⋯ 77000
# 729 0    0     0       2       45  12   NA     0.00    2160   45     ⋯ 88000
# 730 0    0     1       1       30  14   NA     0.00    1715   32     ⋯ 26040
# 731 0    0     0       1       41  12   NA     0.00    3018   42     ⋯ 63500
# 732 0    0     2       0       30  12   NA     0.00    2216   33     ⋯ 12100
# 733 0    0     0       1       53  12   NA     0.00    2499   54     ⋯ 17505
# 734 0    0     0       0       31  12   NA     0.00    2250   37     ⋯ 18000
# 735 0    0     0       2       43  14   NA     0.00    2116   44     ⋯ 28069
# 736 0    0     1       1       31  12   NA     0.00    2016   30     ⋯ 14000
# 737 0    0     0       0       51  12   NA     0.00    2470   60     ⋯  8117
# 738 0    0     0       0       43   9   NA     0.00    1640   45     ⋯ 11895
# 739 0    0     1       2       31  14   NA     0.00    2016   34     ⋯ 45250
# 740 0    0     0       0       48  11   NA     0.00    2185   48     ⋯ 31106
# 741 0    0     1       1       31  12   NA     0.00     800   33     ⋯  4000
# 742 0    0     0       1       44  12   NA     0.00    3022   46     ⋯ 40500
# 743 0    0     0       1       48  11   NA     0.00    1512   50     ⋯ 21620
# 744 0    0     0       1       53  12   NA     0.00    2677   53     ⋯ 23426
# 745 0    0     0       3       42  10   NA     2.75    3150   44     ⋯ 26000
# 746 0    0     2       6       39  12   NA     0.00    1430   34     ⋯  7840
# 747 0    0     1       2       32  10   NA     0.00    3307   36     ⋯  6800
# 748 0    0     0       2       36  12   NA     0.00    3120   39     ⋯  5330
# 749 0    0     0       2       40  13   NA     0.00    3020   43     ⋯ 28200
# 750 0    0     2       3       31  12   NA     0.00    2056   33     ⋯ 10000
# 751 0    0     0       0       43  12   NA     0.00    2383   43     ⋯  9952
# 752 0    0     0       0       60  12   NA     0.00    1705   55     ⋯ 24984
# 753 0    0     0       3       39   9   NA     0.00    3120   48     ⋯ 28363
#     mtr    motheduc fatheduc unem city exper nwifeinc  lwage      expersq
# 1   0.7215 12        7        5.0 0    14    10.910060 1.21015370  196
# 2   0.6615  7        7       11.0 1     5    19.499981 0.32851210   25
# 3   0.6915 12        7        5.0 0    15    12.039910 1.51413774  225
# 4   0.7815  7        7        5.0 0     6     6.799996 0.09212332   36
# 5   0.6215 12       14        9.5 1     7    20.100058 1.52427220   49
# 6   0.6915 14        7        7.5 1    33     9.859054 1.55648005 1089
# 7   0.6915 14        7        5.0 0    11     9.152048 2.12025952  121
# 8   0.6915  3        3        5.0 0    35    10.900038 2.05963421 1225
# 9   0.7515  7        7        3.0 0    24    17.305000 0.75433636  576
# 10  0.6915  7        7        5.0 0    21    12.925000 1.54489934  441
# 11  0.5815 12        3        5.0 0    15    24.299953 1.40192163  225
# 12  0.6215 14        7        5.0 0    14    19.700071 1.52427220  196
# 13  0.7215 16       16        5.0 0     0    15.000008 0.73395324    0
# 14  0.7215 10       10        7.5 1    14    14.600000 0.81836909  196
# 15  0.5815  7        7        7.5 1     6    24.630915 1.30283117   36
# 16  0.7215 16       10        7.5 1     9    17.531027 0.29802838   81
# 17  0.6915 10        7        7.5 1    20    14.099980 1.16760957  400
# 18  0.7215 12       12        7.5 1     6    15.839000 1.64383936   36
# 19  0.6915  7        7        5.0 1    23    14.100000 0.69314718  529
# 20  0.6915 12        7        5.0 0     9    10.299961 2.02193165   81
# 21  0.6215 10       16        7.5 0     5    22.654982 1.25424755   25
# 22  0.7215 12       10        3.0 0    11     8.090048 1.27295768  121
# 23  0.6615  7        3        5.0 1    18    17.479000 1.17865503  324
# 24  0.7215  7        7       11.0 0    15     9.560000 1.17865503  225
# 25  0.7515 12        7        5.0 1     4     8.274953 0.76755869   16
# 26  0.5815 16       14        9.5 1    21    27.349985 1.33181179  441
# 27  0.6915  3        7        9.5 1    31    16.000000 1.38629436  961
# 28  0.6615  3        7       11.0 1     9    16.999983 1.55326962   81
# 29  0.6215 12       12        5.0 0     7    15.100056 1.98181486   49
# 30  0.7215 12       12        9.5 0     7    15.699984 1.76936042   49
# ⋮   ⋮      ⋮        ⋮        ⋮    ⋮    ⋮     ⋮         ⋮          ⋮
# 724 0.7715  7        7        7.5 0    18    12.400    NA         324
# 725 0.7815  0        0        7.5 0     7     6.531    NA          49
# 726 0.6915  3        7       11.0 1    15    22.422    NA         225
# 727 0.6615  7        7       11.0 1     7    22.200    NA          49
# 728 0.4415  7       14       14.0 1     8    77.000    NA          64
# 729 0.4415 10       10       14.0 1     8    88.000    NA          64
# 730 0.6215 12       10       11.0 0     3    26.040    NA           9
# 731 0.4415  7        7        7.5 1    10    63.500    NA         100
# 732 0.7515 10       10        7.5 0     9    12.100    NA          81
# 733 0.7515 12        7        7.5 1    24    17.505    NA         576
# 734 0.6915 10        7        7.5 0    12    18.000    NA         144
# 735 0.6615 12       12       11.0 1     2    28.069    NA           4
# 736 0.7515 12       14       14.0 1     6    14.000    NA          36
# 737 0.7515 10        3        7.5 1    18     8.117    NA         324
# 738 0.7715  7        7        5.0 1    17    11.895    NA         289
# 739 0.4915 16       16        5.0 1     7    45.250    NA          49
# 740 0.6915  7       10        9.5 1     6    31.106    NA          36
# 741 0.8015 12        7        9.5 1    10     4.000    NA         100
# 742 0.5815  7        7        7.5 1     5    40.500    NA          25
# 743 0.7215 10        7        7.5 1     7    21.620    NA          49
# 744 0.7215  0        0        7.5 1    11    23.426    NA         121
# 745 0.6615  3        3       11.0 1    14    26.000    NA         196
# 746 0.9415  7        0        9.5 1     5     7.840    NA          25
# 747 0.7915  7        3        7.5 0     2     6.800    NA           4
# 748 0.7915  7       12       14.0 0     4     5.330    NA          16
# 749 0.6215 10       10        9.5 1     5    28.200    NA          25
# 750 0.7715 12       12        7.5 0    14    10.000    NA         196
# 751 0.7515 10        3        7.5 0     4     9.952    NA          16
# 752 0.6215 12       12       14.0 1    15    24.984    NA         225
# 753 0.6915  7        7       11.0 1    12    28.363    NA         144
# [[1]]
# hours ~ lwage + educ + age + kidslt6 + kidsge6 + nwifeinc
#
# [[2]]
# lwage ~ hours + educ + exper + expersq

# %%
# Зададим инструментальные переменные (экзогенные)
instr = ~ educ + age + kidslt6 + kidsge6 + nwifeinc + exper + expersq

# %%
# Оценим систему одновременных уравнений
mroz.sys = systemfit(sys, inst = instr,
                       method = "2SLS", data = d)
summary(mroz.sys)
# Out:
# systemfit results
# method: 2SLS
#
#          N  DF       SSR detRCov   OLS-R2 McElroy-R2
# system 856 844 713583468  137682 -1.77323   0.764198
#
#       N  DF         SSR         MSE       RMSE        R2    Adj R2
# eq1 428 421 7.13583e+08 1.69497e+06 1301.91096 -1.773232 -1.812756
# eq2 428 423 1.98494e+02 4.69252e-01    0.68502  0.111198  0.102794
#
# The covariance matrix of the residuals
#             eq1         eq2
# eq1 1694972.137 -810.979346
# eq2    -810.979    0.469252
#
# The correlations of the residuals
#           eq1       eq2
# eq1  1.000000 -0.909338
# eq2 -0.909338  1.000000
#
#
# 2SLS estimates for 'eq1' (equation 1)
# Model Formula: hours ~ lwage + educ + age + kidslt6 + kidsge6 + nwifeinc
# Instruments: ~educ + age + kidslt6 + kidsge6 + nwifeinc + exper + expersq
#
#               Estimate Std. Error  t value   Pr(>|t|)
# (Intercept) 2432.19779  594.17186  4.09342 5.0966e-05 ***
# lwage       1544.81851  480.73874  3.21343  0.0014125 **
# educ        -177.44896   58.14260 -3.05196  0.0024175 **
# age          -10.78409    9.57735 -1.12600  0.2608073
# kidslt6     -210.83389  176.93397 -1.19160  0.2340908
# kidsge6      -47.55708   56.91786 -0.83554  0.4038883
# nwifeinc      -9.24912    6.48112 -1.42709  0.1542959
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1301.910956 on 421 degrees of freedom
# Number of observations: 428 Degrees of Freedom: 421
# SSR: 713583269.623238 MSE: 1694972.136872 Root MSE: 1301.910956
# Multiple R-Squared: -1.773232 Adjusted R-Squared: -1.812756
#
#
# 2SLS estimates for 'eq2' (equation 2)
# Model Formula: lwage ~ hours + educ + exper + expersq
# Instruments: ~educ + age + kidslt6 + kidsge6 + nwifeinc + exper + expersq
#
#                 Estimate   Std. Error  t value   Pr(>|t|)
# (Intercept) -0.692789995  0.306600204 -2.25959   0.024355 *
# hours        0.000160806  0.000215408  0.74652   0.455767
# educ         0.111117505  0.015331869  7.24749 2.0308e-12 ***
# exper        0.032645976  0.018061015  1.80754   0.071389 .
# expersq     -0.000676540  0.000442636 -1.52844   0.127152
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.68502 on 423 degrees of freedom
# Number of observations: 428 Degrees of Freedom: 423
# SSR: 198.493796 MSE: 0.469252 Root MSE: 0.68502
# Multiple R-Squared: 0.111198 Adjusted R-Squared: 0.102794
